# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./benchmark.csv')
df
# Out:
#    Размер  Линейный (сек)  Binary (сек)  RBTree (сек)
# 0     100        0.000001  8.300000e-07  8.200000e-07
# 1    1000        0.000003  8.800000e-07  8.900000e-07
# 2   10000        0.000014  7.400000e-07  6.400000e-07
# 3   50000        0.000016  4.500000e-07  3.100000e-07
# 4  100000        0.000028  3.800000e-07  3.400000e-07
# 5  200000        0.000034  5.700000e-07  3.800000e-07
# 6  300000        0.000031  5.700000e-07  4.400000e-07

# %%
g = sns.lineplot(data=df.set_index('Размер'))

# %%
g = sns.lineplot(data=df.set_index('Размер').drop(columns=['Линейный (сек)']))
